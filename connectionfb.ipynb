# %%
import os
from dotenv import load_dotenv
import psycopg2
import pandas as pd

load_dotenv()

conn_params = {
    "dbname": os.getenv("DB_NAME"),
    "user": os.getenv("DB_USER"),
    "password": os.getenv("DB_PASSWORD"),
    "host": os.getenv("DB_HOST"),
    "port": os.getenv("DB_PORT", "5432"),
}

# %%
# 68599
# 27346
#295

entity_id = 72067
import pandas as pd
import psycopg2

with psycopg2.connect(**conn_params) as conn:
    with conn.cursor() as cur:
       
        cur.execute("SELECT creator_id FROM entity WHERE id = %s", (entity_id,))
        row = cur.fetchone()
        if row is None or row[0] is None:
            raise ValueError(f"No se encontró creator_id para entity.id = {entity_id}")
        creator_id = row[0]

        cur.execute("SELECT * FROM file WHERE creator_id = %s", (creator_id,))
        rows = cur.fetchall()
        columns = [desc[0] for desc in cur.description]

files_df = pd.DataFrame(rows, columns=columns)
print(f"creator_id: {creator_id} | filas encontradas en file: {len(files_df)}")
files_df.head(50)
# Out:
# creator_id: 85891 | filas encontradas en file: 6
#         id                                   name  file_type_id  \
# 0  2956827      EDWARD COLE_PELAYO_license_selfie             5
# 1  2956828        EDWARD COLE_PELAYO_license_back             5
# 2  2956829             EDWARD COLE_PELAYO_license             5
# 3  2956830  2025 Certificate of Good Standing.pdf             1
# 4  2956831                       Joe Passport.pdf             1
# 5  2956832               Erin Conrad Passport.pdf             1
#
#                                                  bin  \
# 0  [b'\xff', b'\xd8', b'\xff', b'\xe0', b'\x00', ...
# 1  [b'\xff', b'\xd8', b'\xff', b'\xe0', b'\x00', ...
# 2  [b'\xff', b'\xd8', b'\xff', b'\xe0', b'\x00', ...
# 3  [b'%', b'P', b'D', b'F', b'-', b'1', b'.', b'7...
# 4  [b'%', b'P', b'D', b'F', b'-', b'1', b'.', b'3...
# 5  [b'%', b'P', b'D', b'F', b'-', b'1', b'.', b'3...
#
#                creation_date  creator_id key_path
# 0 2025-08-07 16:20:25.430161       85891     None
# 1 2025-08-07 16:20:25.983139       85891     None
# 2 2025-08-07 16:20:26.596045       85891     None
# 3 2025-08-07 16:21:13.505032       85891     None
# 4 2025-08-07 16:24:05.899560       85891     None
# 5 2025-08-07 16:28:37.228136       85891     None

# %%
import re
import mimetypes
from pathlib import Path
import pandas as pd

OUTPUT_DIR = Path("files_bajados")
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

INVALID_WIN_CHARS = r"<>:\\/\|\?\*\"" 
_invalid_chars_pattern = re.compile(f"[{re.escape(INVALID_WIN_CHARS)}]+")

def sanitize_filename(name: str) -> str:
    if not isinstance(name, str) or not name.strip():
        return ""

    cleaned = _invalid_chars_pattern.sub("_", name).strip()
    cleaned = re.sub(r"\s+", " ", cleaned)

    reserved = {"CON", "PRN", "AUX", "NUL", *(f"COM{i}" for i in range(1, 10)), *(f"LPT{i}" for i in range(1, 10))}
    if cleaned.upper() in reserved:
        cleaned = f"_{cleaned}"
    return cleaned

def ensure_unique_path(base_path: Path) -> Path:
    if not base_path.exists():
        return base_path
    stem, suffix = base_path.stem, base_path.suffix
    counter = 1
    while True:
        candidate = base_path.with_name(f"{stem}_{counter}{suffix}")
        if not candidate.exists():
            return candidate
        counter += 1


def guess_extension_from_row(row: pd.Series) -> str:
    mime = None
    for key in ("content_type", "mime_type", "mimetype", "mime"):
        if key in row and isinstance(row[key], str) and row[key].strip():
            mime = row[key].strip()
            break
    if mime:
        ext = mimetypes.guess_extension(mime, strict=False)
        if ext:
            return ext

    if "extension" in row and isinstance(row["extension"], str) and row["extension"].strip():
        ext = row["extension"].strip()
        if not ext.startswith("."):
            ext = "." + ext
        return ext
    return ""

def guess_extension_from_bytes(binary_bytes: bytes) -> str:
    # Firmas mágicas comunes
    if binary_bytes.startswith(b"\xFF\xD8\xFF"):
        return ".jpg"
    if binary_bytes.startswith(b"\x89PNG\r\n\x1a\n"):
        return ".png"
    if binary_bytes.startswith(b"GIF87a") or binary_bytes.startswith(b"GIF89a"):
        return ".gif"
    if binary_bytes.startswith(b"%PDF"):
        return ".pdf"
    if binary_bytes.startswith(b"PK\x03\x04"):
        return ".zip"  # docx/xlsx/pptx también son zip
    if binary_bytes.startswith(b"Rar!\x1a\x07\x00"):
        return ".rar"
    if binary_bytes.startswith(b"7z\xBC\xAF'\x1C"):
        return ".7z"
    return ""


saved_records = []
skipped_rows = 0

if "bin" not in files_df.columns:
    raise KeyError("La columna 'bin' no existe en files_df. Verifica el DataFrame.")

for idx, row in files_df.iterrows():
    binary_data = row["bin"]
    if pd.isna(binary_data):
        skipped_rows += 1
        continue

    if isinstance(binary_data, memoryview):
        binary_bytes = binary_data.tobytes()
    elif isinstance(binary_data, (bytes, bytearray)):
        binary_bytes = bytes(binary_data)
    else:
        skipped_rows += 1
        continue

    base_name = None
    for key in ("filename", "file_name", "name", "original_name", "original_filename", "title"):
        if key in row and isinstance(row[key], str) and row[key].strip():
            base_name = row[key].strip()
            break
    if not base_name:
        identifier = row["id"] if "id" in row and pd.notna(row["id"]) else idx
        base_name = f"file_{identifier}"

    base_name = sanitize_filename(base_name)

    # Resolución de extensión: nombre > firma mágica > metadatos > .bin
    has_name_ext = "." in Path(base_name).name and not base_name.endswith(".")
    ext_from_magic = guess_extension_from_bytes(binary_bytes)
    ext_from_row = guess_extension_from_row(row)

    if has_name_ext:
        file_name = base_name
    elif ext_from_magic:
        file_name = base_name + ext_from_magic
    elif ext_from_row:
        file_name = base_name + ext_from_row
    else:
        file_name = base_name + ".bin"

    out_path = ensure_unique_path(OUTPUT_DIR / file_name)

    with open(out_path, "wb") as f:
        f.write(binary_bytes)

    saved_records.append({
        "index": idx,
        "id": row.get("id", None),
        "creator_id": row.get("creator_id", None),
        "path": str(out_path),
        "size_bytes": len(binary_bytes),
    })

result_df = pd.DataFrame(saved_records)
print(f"Guardados: {len(saved_records)} | Omitidos: {skipped_rows} | Carpeta: {OUTPUT_DIR.resolve()}")
result_df.head(50)
# Out:
# Guardados: 6 | Omitidos: 0 | Carpeta: C:\Users\felip\OneDrive\Escritorio\connectionAgent\files_bajados
#    index       id  creator_id  \
# 0      0  2956827       85891
# 1      1  2956828       85891
# 2      2  2956829       85891
# 3      3  2956830       85891
# 4      4  2956831       85891
# 5      5  2956832       85891
#
#                                                 path  size_bytes
# 0  files_bajados\EDWARD COLE_PELAYO_license_selfi...      423564
# 1  files_bajados\EDWARD COLE_PELAYO_license_back_...      468778
# 2     files_bajados\EDWARD COLE_PELAYO_license_1.jpg      426781
# 3  files_bajados\2025 Certificate of Good Standin...      368738
# 4                   files_bajados\Joe Passport_1.pdf     3756573
# 5           files_bajados\Erin Conrad Passport_1.pdf     1058424

# %%
# 68599
# 27346
#295
#72067
#entity_id = 72023

# %%
import psycopg2
import pandas as pd

with psycopg2.connect(**conn_params) as conn:
    with conn.cursor() as cur:
        cur.execute(
            """
            SELECT id, entity_id, kyb_provider_id, kyb_provider_data, creation_date
            FROM com_kyb_check
            WHERE entity_id = %s
            ORDER BY creation_date DESC
            """,
            (entity_id,)
        )
        rows = cur.fetchall()
        columns = [d[0] for d in cur.description]

kyb_df = pd.DataFrame(rows, columns=columns)
kyb_df.head(10)
# Out:
#      id  entity_id kyb_provider_id  \
# 0  7746      72067            KYCP
# 1  7744      72067           ALLOY
#
#                                    kyb_provider_data  \
# 0  {'id': 3302, 'uid': 'N4OZZD', 'result': 'Ok', ...
# 1  {'_links': {'self': {'href': '/v1/journeys/J-D...
#
#                creation_date
# 0 2025-08-07 16:31:42.045835
# 1 2025-08-07 16:18:10.031352

# %%
events = kyb_df.iloc[1]['kyb_provider_data']['_embedded']['events']
evaluation_token = next((event['evaluation_token'] for event in reversed(events) if event['type'] == 'completed_evaluation'), None)
print(evaluation_token)
# Out:
# L-zeShTGEsXIciRVrIqIqX

# %%
import requests

def get_alloy_evaluation(evtoken):
    base_url = "https://api.alloy.co/v1/evaluations"
    url = f"{base_url}/{evtoken}"
    username = 'VNhUFeEXunqrCscAMyyHU04ZYpt2tvKL'
    password = "a1l2jmInL00zjhJohly6MxWdV9aCogTn"
    try:
        
        response = requests.get(
            url,
            auth=(username, password),
            headers={
                'Content-Type': 'application/json',
                'Accept': 'application/json'
            }
        )
         
        response.raise_for_status()
        return response.json()
        
    except requests.exceptions.HTTPError as e:
        print(f"Error HTTP: {e}")
        return None

# %%
get_alloy_evaluation(evaluation_token)
# Out:
# {'status_code': 201,
#  'error': None,
#  'timestamp': 1754584315583,
#  'evaluation_token': 'L-zeShTGEsXIciRVrIqIqX',
#  'entity_token': 'B-NHj45QpIRYs0feAi0u46',
#  'parent_entity_token': None,
#  'external_entity_id': '72067b',
#  'application_token': '1sCQ66OIXtBqbyGJigyAF8EfQGFglcK2',
#  'application_version_id': 3,
#  'champion_challenger_id': None,
#  'summary': {'result': 'success',
#   'score': 1,
#   'tags': ['Representative Match',
#    'Business Address Matched',
#    'FEIN Found',
#    'Business Name Matched',
#    'Secretary of State Match'],
#   'outcome_reasons': [],
#   'outcome': 'Approved',
#   'services': {'Middesk': 'executed'},
#   'alloy_fraud_score': None},
#  'supplied': {'type': 'business.updated',
#   'data': {'object': {'object': 'business',
#     'id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#     'external_id': 'B-NHj45QpIRYs0feAi0u46',
#     'unique_external_id': None,
#     'name': 'Cactus Communications, Inc.',
#     'created_at': '2025-08-07T16:31:27.644Z',
#     'updated_at': '2025-08-07T16:31:53.973Z',
#     'status': 'in_review',
#     'tags': [],
#     'requester': {'id': 'c37e0821-c376-4b0b-9b0c-6a42489bbe7e',
#      'type': 'account',
#      'name': 'OnTop',
#      'requested_at': '2025-08-07T16:31:27.689Z'},
#     'assignee_id': 'f72203c2-df8e-4e40-8d79-87cd8490dec8',
#     'review': {'object': 'review',
#      'id': 'e2422be7-30dd-45d8-adff-cbb36a17314c',
#      'created_at': '2025-08-07T16:31:27.949Z',
#      'updated_at': '2025-08-07T16:31:27.949Z',
#      'completed_at': None,
#      'tasks': [{'category': 'address',
#        'key': 'location_frequency',
#        'label': 'Office Address',
#        'message': '21–100 businesses use this location',
#        'name': 'address',
#        'status': 'warning',
#        'sub_label': 'Moderate frequency',
#        'sources': []},
#       {'category': 'address',
#        'key': 'address_risk',
#        'label': 'Address Risk',
#        'message': 'Address risk is moderate',
#        'name': 'address',
#        'status': 'warning',
#        'sub_label': 'Moderate',
#        'sources': []},
#       {'category': 'sos',
#        'key': 'sos_inactive',
#        'label': 'SOS Filings',
#        'message': '3 of 5 filings are Inactive',
#        'name': 'sos',
#        'status': 'warning',
#        'sub_label': 'Partially Inactive',
#        'sources': []},
#       {'category': 'name',
#        'key': 'name',
#        'label': 'Business Name',
#        'message': 'Match identified to the submitted Business Name',
#        'name': 'name',
#        'status': 'success',
#        'sub_label': 'Verified',
#        'sources': [{'id': 'abc1993c-d065-468a-9361-7354c52ece4c',
#          'type': 'name',
#          'metadata': {'name': 'Cactus Communications, Inc.',
#           'submitted': True}}]},
#       {'category': 'address',
#        'key': 'address_verification',
#        'label': 'Office Address',
#        'message': 'Match identified to the submitted Office Address',
#        'name': 'address',
#        'status': 'success',
#        'sub_label': 'Verified',
#        'sources': [{'id': '4ced7bc6-72d8-472b-b468-533496771ddb',
#          'type': 'address',
#          'metadata': {'city': 'Denver',
#           'state': 'CO',
#           'submitted': False,
#           'postal_code': '80202-1067',
#           'full_address': '2128 15th St Ste 100, Denver, CO 80202-1067',
#           'address_line1': '2128 15th St Ste 100',
#           'address_line2': None}},
#         {'id': '013aab85-4f39-40aa-a87d-453d9ddaf00e',
#          'type': 'address',
#          'metadata': {'city': 'Denver',
#           'state': 'CO',
#           'submitted': True,
#           'postal_code': '80202-6125',
#           'full_address': '2128 15th St, Denver, CO 80202-6125',
#           'address_line1': '2128 15th St',
#           'address_line2': None}}]},
#       {'category': 'address',
#        'key': 'address_deliverability',
#        'label': 'Office Address',
#        'message': 'The USPS is able to deliver mail to the submitted Office Address',
#        'name': 'address',
#        'status': 'success',
#        'sub_label': 'Deliverable',
#        'sources': []},
#       {'category': 'address',
#        'key': 'address_property_type',
#        'label': 'Office Address',
#        'message': 'Submitted Office Address is a Commercial property',
#        'name': 'address',
#        'status': 'success',
#        'sub_label': 'Commercial',
#        'sources': []},
#       {'category': 'people',
#        'key': 'person_verification',
#        'label': 'People',
#        'message': 'Match identified to the submitted person',
#        'name': 'people',
#        'status': 'success',
#        'sub_label': 'Verified',
#        'sources': [{'id': '2102187e-86fa-4856-b695-f3ad22876032',
#          'type': 'person',
#          'metadata': {'name': 'Joseph Conrad', 'submitted': True}}]},
#       {'category': 'sos',
#        'key': 'sos_match',
#        'label': 'SOS Filings',
#        'message': 'The business is Active in the state of the submitted Office Address',
#        'name': 'sos',
#        'status': 'success',
#        'sub_label': 'Submitted Active',
#        'sources': []},
#       {'category': 'sos',
#        'key': 'sos_active',
#        'label': 'SOS Filings',
#        'message': '2 of 5 filings are Active',
#        'name': 'sos',
#        'status': 'success',
#        'sub_label': 'Active',
#        'sources': []},
#       {'category': 'sos',
#        'key': 'sos_domestic_sub_status',
#        'label': 'SOS Domestic Sub‑status',
#        'message': 'The domestic registration is in Good Standing.',
#        'name': 'sos',
#        'status': 'success',
#        'sub_label': 'Good Standing',
#        'sources': []},
#       {'category': 'sos',
#        'key': 'sos_domestic',
#        'label': 'SOS Filings',
#        'message': 'Active domestic filing found',
#        'name': 'sos',
#        'status': 'success',
#        'sub_label': 'Domestic Active',
#        'sources': []},
#       {'category': 'tin',
#        'key': 'tin',
#        'label': 'TIN Match',
#        'message': 'The IRS has a record for the submitted TIN and Business Name combination',
#        'name': 'tin',
#        'status': 'success',
#        'sub_label': 'Found',
#        'sources': []},
#       {'category': 'watchlist',
#        'key': 'watchlist',
#        'label': 'Watchlist',
#        'message': 'No Watchlist hits were identified',
#        'name': 'watchlist',
#        'status': 'success',
#        'sub_label': 'No Hits',
#        'sources': []},
#       {'category': 'industry',
#        'key': 'industry',
#        'label': 'Industry Classification',
#        'message': 'This business likely does not operate in a high risk industry',
#        'name': 'industry',
#        'status': 'success',
#        'sub_label': 'No Hits',
#        'sources': []},
#       {'category': 'website',
#        'key': 'website_status',
#        'label': 'Website',
#        'message': 'Website was Online when the business record was ordered',
#        'name': 'website',
#        'status': 'success',
#        'sub_label': 'Online',
#        'sources': []},
#       {'category': 'website',
#        'key': 'website_verification',
#        'label': 'Website',
#        'message': 'Successfully found entity details on the submitted Website',
#        'name': 'website',
#        'status': 'success',
#        'sub_label': 'Verified',
#        'sources': []}],
#      'assignee': {'object': 'user',
#       'id': 'f72203c2-df8e-4e40-8d79-87cd8490dec8',
#       'name': 'romy+ontop@alloy.com',
#       'email': 'romy+ontop@alloy.com',
#       'roles': ['admin', 'member'],
#       'image_url': '//www.gravatar.com/avatar/b13dbcfc78841de4e29ddc2d80b22450?s=64&d=https%3A%2F%2Fapp.middesk.com%2Fimages%2Fdefault-avatar.png',
#       'directory_managed': False,
#       'last_login_at': '2025-02-19T05:01:07.343Z',
#       'settings': {'receives_agent_emails': False},
#       'created_at': '2024-04-01T18:41:44.669Z'}},
#     'tin': {'name': 'CACTUS COMMUNICATIONS',
#      'mismatch': False,
#      'unknown': False,
#      'verified': True,
#      'error': None,
#      'updated_at': '2025-08-07T16:31:28.184Z',
#      'issued': True,
#      'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#      'tin': '84-1183960'},
#     'business_batch_id': None,
#     'formation': {'entity_type': 'CORPORATION',
#      'formation_date': '1991-11-05',
#      'formation_state': 'CO',
#      'created_at': '2025-08-07T16:31:28.658Z',
#      'updated_at': '2025-08-07T16:31:28.658Z'},
#     'website': {'object': 'website',
#      'id': 'fb22c025-3de2-443a-83d7-22209906c87e',
#      'url': 'http://cactusinc.com',
#      'created_at': '2025-08-07T16:31:27.659Z',
#      'updated_at': '2025-08-07T16:31:53.527Z',
#      'status': 'online',
#      'http_status_code': 200,
#      'title': 'Cactus | Full-Service Advertising Agency | Creative | Strategy | Media',
#      'description': 'Cactus is a full-service creative agency that uses the principles of behavior change to help brands grow. Services include brand strategy, creative, media, design, digital, and more.',
#      'domain': {'domain': 'CACTUSINC.COM',
#       'domain_id': '1733244769_DOMAIN_COM-VRSN',
#       'creation_date': '2012-07-11T18:19:49.000Z',
#       'expiration_date': '2026-07-11T18:19:49.000Z',
#       'registrar': {'organization': None,
#        'name': 'Cloudflare, Inc.',
#        'url': None}},
#      'pages': [{'url': 'https://cactusinc.com/',
#        'category': 'home',
#        'screenshot_url': 'https://static.middesk.com/websites/cactusinc.com/screenshots/home--1754584301.png'},
#       {'url': 'https://cactusinc.com/services',
#        'category': 'service',
#        'screenshot_url': 'https://static.middesk.com/websites/cactusinc.com/screenshots/service--1754584308.png'},
#       {'url': 'https://cactusinc.com/contact',
#        'category': 'contact',
#        'screenshot_url': 'https://static.middesk.com/websites/cactusinc.com/screenshots/contact--1754584308.png'},
#       {'url': 'https://cactusinc.com/about',
#        'category': 'about',
#        'screenshot_url': 'https://static.middesk.com/websites/cactusinc.com/screenshots/about--1754584309.png'},
#       {'url': 'https://cactusinc.com/people',
#        'category': 'careers',
#        'screenshot_url': 'https://static.middesk.com/websites/cactusinc.com/screenshots/careers--1754584312.png'}],
#      'parked': False,
#      'submitted': True,
#      'error': None,
#      'category': 'Standard',
#      'platform': None,
#      'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#      'business_name_match': False,
#      'phone_numbers': [],
#      'people': None,
#      'addresses': [{'object': 'address',
#        'address_line1': '2128 15th St',
#        'address_line2': None,
#        'city': 'Denver',
#        'state': 'CO',
#        'postal_code': '80202-6125',
#        'full_address': '2128 15th St, Denver, CO 80202-6125',
#        'submitted': True,
#        'id': '013aab85-4f39-40aa-a87d-453d9ddaf00e',
#        'sources': [{'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#          'type': 'registration',
#          'metadata': {'state': 'FL',
#           'labels': ['mailing'],
#           'status': 'inactive',
#           'file_number': 'F19000001856',
#           'jurisdiction': 'FOREIGN'}},
#         {'id': '2d116386-a7c2-4012-815a-56c6e4f22f8b',
#          'type': 'registration',
#          'metadata': {'state': 'CO',
#           'labels': ['primary'],
#           'status': 'active',
#           'file_number': '19911088860',
#           'jurisdiction': 'DOMESTIC'}},
#         {'id': 'cd45037e-591c-4d3d-a32f-bdd70b23eeea',
#          'type': 'registration',
#          'metadata': {'state': 'RI',
#           'labels': ['mailing'],
#           'status': 'inactive',
#           'file_number': '1018589',
#           'jurisdiction': 'FOREIGN'}},
#         {'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#          'type': 'registration',
#          'metadata': {'state': 'KY',
#           'labels': ['primary'],
#           'status': 'inactive',
#           'file_number': '1245663',
#           'jurisdiction': 'FOREIGN'}},
#         {'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#          'type': 'registration',
#          'metadata': {'state': 'NC',
#           'labels': ['mailing'],
#           'status': 'active',
#           'file_number': '2212862',
#           'jurisdiction': 'FOREIGN'}},
#         {'id': 'fb22c025-3de2-443a-83d7-22209906c87e',
#          'type': 'website',
#          'metadata': {'url': 'http://cactusinc.com'}},
#         {'id': '78fc3102-d8b3-413f-b7a4-ee1b73d54a00',
#          'type': 'sam_entity_extract',
#          'metadata': {'labels': ['physical', 'mailing']}},
#         {'id': '70fda7a8-74f5-40c9-925e-47bf492a8d49',
#          'type': 'lien',
#          'metadata': {'state': 'CO', 'labels': []}}]}],
#      'email_addresses': None},
#     'watchlist': {'object': 'watchlist',
#      'id': '43e24a01-80db-447e-801e-a1c9eff042f8',
#      'hit_count': 0,
#      'agencies': [{'abbr': 'OFAC',
#        'name': 'Office of Foreign Assets Control',
#        'org': 'U.S. Department of Treasury'},
#       {'abbr': 'BIS',
#        'name': 'Bureau of Industry and Security',
#        'org': 'U.S. Department of Commerce'},
#       {'abbr': 'DDTC',
#        'name': 'Directorate of Defense Trade Controls',
#        'org': 'U.S. Department of State'},
#       {'abbr': 'ISN',
#        'name': 'Bureau of International Security and Non-Proliferation',
#        'org': 'U.S. Department of State'}],
#      'lists': [{'object': 'watchlist_source',
#        'agency': 'Office of Foreign Assets Control',
#        'agency_abbr': 'OFAC',
#        'organization': 'U.S. Department of Treasury',
#        'title': 'Capta List',
#        'abbr': 'CAP',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Bureau of Industry and Security',
#        'agency_abbr': 'BIS',
#        'organization': 'U.S. Department of Commerce',
#        'title': 'Denied Persons List',
#        'abbr': 'DPL',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Directorate of Defense Trade Controls',
#        'agency_abbr': 'DDTC',
#        'organization': 'U.S. Department of State',
#        'title': 'AECA/ITAR Debarred',
#        'abbr': 'DTC',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Bureau of Industry and Security',
#        'agency_abbr': 'BIS',
#        'organization': 'U.S. Department of Commerce',
#        'title': 'Entity List',
#        'abbr': 'EL',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Office of Foreign Assets Control',
#        'agency_abbr': 'OFAC',
#        'organization': 'U.S. Department of Treasury',
#        'title': 'Foreign Sanctions Evaders',
#        'abbr': 'FSE',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Bureau of International Security and Non-Proliferation',
#        'agency_abbr': 'ISN',
#        'organization': 'U.S. Department of State',
#        'title': 'Nonproliferation Sanctions',
#        'abbr': 'ISN',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Bureau of Industry and Security',
#        'agency_abbr': 'BIS',
#        'organization': 'U.S. Department of Commerce',
#        'title': 'Military End User',
#        'abbr': 'MEU',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Office of Foreign Assets Control',
#        'agency_abbr': 'OFAC',
#        'organization': 'U.S. Department of Treasury',
#        'title': 'Non-SDN Chinese Military-Industrial Complex Companies List',
#        'abbr': 'NS-CMIC',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Office of Foreign Assets Control',
#        'agency_abbr': 'OFAC',
#        'organization': 'U.S. Department of Treasury',
#        'title': 'Non-SDN Iranian Sanctions',
#        'abbr': 'NS-ISA',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Office of Foreign Assets Control',
#        'agency_abbr': 'OFAC',
#        'organization': 'U.S. Department of Treasury',
#        'title': 'Non-SDN Menu-Based Sanctions',
#        'abbr': 'NS-MBS',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Office of Foreign Assets Control',
#        'agency_abbr': 'OFAC',
#        'organization': 'U.S. Department of Treasury',
#        'title': 'Palestinian Legislative Council',
#        'abbr': 'PLC',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Office of Foreign Assets Control',
#        'agency_abbr': 'OFAC',
#        'organization': 'U.S. Department of Treasury',
#        'title': 'Specially Designated Nationals',
#        'abbr': 'SDN',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Office of Foreign Assets Control',
#        'agency_abbr': 'OFAC',
#        'organization': 'U.S. Department of Treasury',
#        'title': 'Sectoral Sanctions Identifications',
#        'abbr': 'SSI',
#        'results': []},
#       {'object': 'watchlist_source',
#        'agency': 'Bureau of Industry and Security',
#        'agency_abbr': 'BIS',
#        'organization': 'U.S. Department of Commerce',
#        'title': 'Unverified List',
#        'abbr': 'UVL',
#        'results': []}],
#      'people': [{'object': 'person',
#        'name': 'Cole Pelayo',
#        'submitted': True,
#        'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#        'sources': [],
#        'titles': [],
#        'people_bankruptcies': []},
#       {'object': 'person',
#        'name': 'Erin Conrrad',
#        'submitted': True,
#        'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#        'sources': [],
#        'titles': [],
#        'people_bankruptcies': []},
#       {'object': 'person',
#        'name': 'Joseph Conrad',
#        'submitted': True,
#        'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#        'sources': [{'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#          'type': 'registration',
#          'metadata': {'state': 'FL',
#           'status': 'inactive',
#           'file_number': 'F19000001856',
#           'jurisdiction': 'FOREIGN'}},
#         {'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#          'type': 'registration',
#          'metadata': {'state': 'NC',
#           'status': 'active',
#           'file_number': '2212862',
#           'jurisdiction': 'FOREIGN'}},
#         {'id': '2d116386-a7c2-4012-815a-56c6e4f22f8b',
#          'type': 'registration',
#          'metadata': {'state': 'CO',
#           'status': 'active',
#           'file_number': '19911088860',
#           'jurisdiction': 'DOMESTIC'}},
#         {'id': 'cd45037e-591c-4d3d-a32f-bdd70b23eeea',
#          'type': 'registration',
#          'metadata': {'state': 'RI',
#           'status': 'inactive',
#           'file_number': '1018589',
#           'jurisdiction': 'FOREIGN'}},
#         {'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#          'type': 'registration',
#          'metadata': {'state': 'KY',
#           'status': 'inactive',
#           'file_number': '1245663',
#           'jurisdiction': 'FOREIGN'}}],
#        'titles': [{'object': 'person_title', 'title': 'CHAIRMAN'},
#         {'object': 'person_title', 'title': 'CHIEF EXECUTIVE OFFICER'},
#         {'object': 'person_title', 'title': 'PRESIDENT'},
#         {'object': 'person_title', 'title': 'REGISTERED AGENT'}],
#        'people_bankruptcies': []},
#       {'object': 'person',
#        'name': 'KRISTINA K BYERS',
#        'submitted': False,
#        'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#        'sources': [{'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#          'type': 'registration',
#          'metadata': {'state': 'FL',
#           'status': 'inactive',
#           'file_number': 'F19000001856',
#           'jurisdiction': 'FOREIGN'}},
#         {'id': 'cd45037e-591c-4d3d-a32f-bdd70b23eeea',
#          'type': 'registration',
#          'metadata': {'state': 'RI',
#           'status': 'inactive',
#           'file_number': '1018589',
#           'jurisdiction': 'FOREIGN'}}],
#        'titles': [{'object': 'person_title', 'title': 'CFO'},
#         {'object': 'person_title', 'title': 'DIRECTOR'}],
#        'people_bankruptcies': []},
#       {'object': 'person',
#        'name': 'SHEARER NORMAN',
#        'submitted': False,
#        'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#        'sources': [{'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#          'type': 'registration',
#          'metadata': {'state': 'FL',
#           'status': 'inactive',
#           'file_number': 'F19000001856',
#           'jurisdiction': 'FOREIGN'}},
#         {'id': 'cd45037e-591c-4d3d-a32f-bdd70b23eeea',
#          'type': 'registration',
#          'metadata': {'state': 'RI',
#           'status': 'inactive',
#           'file_number': '1018589',
#           'jurisdiction': 'FOREIGN'}},
#         {'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#          'type': 'registration',
#          'metadata': {'state': 'KY',
#           'status': 'inactive',
#           'file_number': '1245663',
#           'jurisdiction': 'FOREIGN'}}],
#        'titles': [{'object': 'person_title', 'title': 'CCO'},
#         {'object': 'person_title', 'title': 'PARTNER'}],
#        'people_bankruptcies': []},
#       {'object': 'person',
#        'name': 'SOMERON LISA V',
#        'submitted': False,
#        'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#        'sources': [{'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#          'type': 'registration',
#          'metadata': {'state': 'FL',
#           'status': 'inactive',
#           'file_number': 'F19000001856',
#           'jurisdiction': 'FOREIGN'}}],
#        'titles': [{'object': 'person_title', 'title': 'DIRECTOR'}],
#        'people_bankruptcies': []},
#       {'object': 'person',
#        'name': 'KY SECRETARY OF STATE',
#        'submitted': False,
#        'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#        'sources': [{'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#          'type': 'registration',
#          'metadata': {'state': 'KY',
#           'status': 'inactive',
#           'file_number': '1245663',
#           'jurisdiction': 'FOREIGN'}}],
#        'titles': [{'object': 'person_title', 'title': 'REGISTERED AGENT'}],
#        'people_bankruptcies': []},
#       {'object': 'person',
#        'name': 'Graham, Jeff',
#        'submitted': False,
#        'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#        'sources': [{'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#          'type': 'registration',
#          'metadata': {'state': 'NC',
#           'status': 'active',
#           'file_number': '2212862',
#           'jurisdiction': 'FOREIGN'}}],
#        'titles': [{'object': 'person_title', 'title': 'TREASURER'}],
#        'people_bankruptcies': []},
#       {'object': 'person',
#        'name': 'VanSomeren, Lisa',
#        'submitted': False,
#        'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#        'sources': [{'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#          'type': 'registration',
#          'metadata': {'state': 'NC',
#           'status': 'active',
#           'file_number': '2212862',
#           'jurisdiction': 'FOREIGN'}}],
#        'titles': [{'object': 'person_title', 'title': 'SECRETARY'}],
#        'people_bankruptcies': []}]},
#     'names': [{'object': 'name',
#       'id': 'abc1993c-d065-468a-9361-7354c52ece4c',
#       'name': 'Cactus Communications, Inc.',
#       'submitted': True,
#       'type': 'legal',
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [{'id': '78fc3102-d8b3-413f-b7a4-ee1b73d54a00',
#         'type': 'sam_entity_extract',
#         'metadata': {}},
#        {'id': '70fda7a8-74f5-40c9-925e-47bf492a8d49',
#         'type': 'lien',
#         'metadata': {'state': 'CO'}},
#        {'id': '2d116386-a7c2-4012-815a-56c6e4f22f8b',
#         'type': 'registration',
#         'metadata': {'state': 'CO',
#          'status': 'active',
#          'file_number': '19911088860',
#          'jurisdiction': 'DOMESTIC'}},
#        {'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#         'type': 'registration',
#         'metadata': {'state': 'NC',
#          'status': 'active',
#          'file_number': '2212862',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#         'type': 'registration',
#         'metadata': {'state': 'FL',
#          'status': 'inactive',
#          'file_number': 'F19000001856',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#         'type': 'registration',
#         'metadata': {'state': 'KY',
#          'status': 'inactive',
#          'file_number': '1245663',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': 'cd45037e-591c-4d3d-a32f-bdd70b23eeea',
#         'type': 'registration',
#         'metadata': {'state': 'RI',
#          'status': 'inactive',
#          'file_number': '1018589',
#          'jurisdiction': 'FOREIGN'}}]},
#      {'object': 'name',
#       'id': 'b9e2d5a8-7862-429b-8e4d-03c32dbdf872',
#       'name': 'CACTUS MARKETING COMMUNICATIONS, INC.',
#       'submitted': False,
#       'type': None,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [{'id': 'e86a786d-9961-481a-926b-41c8acf93218',
#         'type': 'form_5500',
#         'metadata': {'ack_id': '20250717100726NAL0000087793001',
#          'plan_year': 2024}}]}],
#     'addresses': [{'object': 'address',
#       'address_line1': '2128 15th St',
#       'address_line2': None,
#       'city': 'Denver',
#       'state': 'CO',
#       'postal_code': '80202-6125',
#       'full_address': '2128 15th St, Denver, CO 80202-6125',
#       'submitted': True,
#       'id': '013aab85-4f39-40aa-a87d-453d9ddaf00e',
#       'latitude': 39.75408027249011,
#       'longitude': -105.0062589964369,
#       'property_type': 'COMMERCIAL',
#       'deliverable': True,
#       'deliverability_analysis': None,
#       'street_view_available': True,
#       'labels': [],
#       'created_at': '2025-08-07T16:31:27.663Z',
#       'updated_at': '2025-08-07T16:31:28.303Z',
#       'registered_agent_name': None,
#       'cmra': False,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'location_count': 21,
#       'is_registered_agent': False,
#       'sources': [{'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#         'type': 'registration',
#         'metadata': {'state': 'FL',
#          'labels': ['mailing'],
#          'status': 'inactive',
#          'file_number': 'F19000001856',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': '2d116386-a7c2-4012-815a-56c6e4f22f8b',
#         'type': 'registration',
#         'metadata': {'state': 'CO',
#          'labels': ['primary'],
#          'status': 'active',
#          'file_number': '19911088860',
#          'jurisdiction': 'DOMESTIC'}},
#        {'id': 'cd45037e-591c-4d3d-a32f-bdd70b23eeea',
#         'type': 'registration',
#         'metadata': {'state': 'RI',
#          'labels': ['mailing'],
#          'status': 'inactive',
#          'file_number': '1018589',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#         'type': 'registration',
#         'metadata': {'state': 'KY',
#          'labels': ['primary'],
#          'status': 'inactive',
#          'file_number': '1245663',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#         'type': 'registration',
#         'metadata': {'state': 'NC',
#          'labels': ['mailing'],
#          'status': 'active',
#          'file_number': '2212862',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': 'fb22c025-3de2-443a-83d7-22209906c87e',
#         'type': 'website',
#         'metadata': {'url': 'http://cactusinc.com'}},
#        {'id': '78fc3102-d8b3-413f-b7a4-ee1b73d54a00',
#         'type': 'sam_entity_extract',
#         'metadata': {'labels': ['physical', 'mailing']}},
#        {'id': '70fda7a8-74f5-40c9-925e-47bf492a8d49',
#         'type': 'lien',
#         'metadata': {'state': 'CO', 'labels': []}}],
#       'rating': {'indicators': [{'type': 'valid_us_address',
#          'name': 'Valid US address',
#          'rating': 'positive',
#          'value': 'valid',
#          'description': 'Valid'},
#         {'type': 'deliverability',
#          'name': 'Deliverability',
#          'rating': 'positive',
#          'value': 'deliverable',
#          'description': 'Deliverable'},
#         {'type': 'geographical_location',
#          'name': 'Geographical location',
#          'rating': 'positive',
#          'value': 'us',
#          'description': 'US'},
#         {'type': 'registered_agent',
#          'name': 'Registered agent',
#          'rating': 'positive',
#          'value': 'not_registered_agent',
#          'description': 'Not a registered agent'},
#         {'type': 'private_mailbox',
#          'name': 'Private mailbox',
#          'rating': 'positive',
#          'value': 'not_private_mailbox',
#          'description': 'Not a private mailbox'},
#         {'type': 'location_frequency',
#          'name': 'Location frequency',
#          'rating': 'neutral',
#          'value': '21-100_businesses',
#          'description': '21-100 businesses'},
#         {'type': 'property_type',
#          'name': 'Property type',
#          'rating': 'positive',
#          'value': 'commercial',
#          'description': 'Commercial'},
#         {'type': 'virtual_address',
#          'name': 'Virtual address',
#          'rating': 'positive',
#          'value': 'not_virtual_address',
#          'description': 'Not a virtual address'}],
#        'risk_rating': 'moderate'}},
#      {'object': 'address',
#       'address_line1': '1025 Capital Center Dr Ste 201',
#       'address_line2': None,
#       'city': 'Frankfort',
#       'state': 'KY',
#       'postal_code': '40601-8205',
#       'full_address': '1025 Capital Center Dr Ste 201, Frankfort, KY 40601-8205',
#       'submitted': False,
#       'id': '79f552cf-d152-4f14-9e01-fa3dab9f9983',
#       'latitude': 38.16305160522461,
#       'longitude': -84.8199462890625,
#       'property_type': 'COMMERCIAL',
#       'deliverable': True,
#       'deliverability_analysis': None,
#       'street_view_available': None,
#       'labels': [],
#       'created_at': '2025-08-07T16:31:28.119Z',
#       'updated_at': '2025-08-07T16:31:28.119Z',
#       'registered_agent_name': None,
#       'cmra': False,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'location_count': 2,
#       'is_registered_agent': False,
#       'sources': [{'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#         'type': 'registration',
#         'metadata': {'state': 'KY',
#          'labels': ['registered_agent'],
#          'status': 'inactive',
#          'file_number': '1245663',
#          'jurisdiction': 'FOREIGN'}}],
#       'rating': {'indicators': [{'type': 'valid_us_address',
#          'name': 'Valid US address',
#          'rating': 'positive',
#          'value': 'valid',
#          'description': 'Valid'},
#         {'type': 'deliverability',
#          'name': 'Deliverability',
#          'rating': 'positive',
#          'value': 'deliverable',
#          'description': 'Deliverable'},
#         {'type': 'geographical_location',
#          'name': 'Geographical location',
#          'rating': 'positive',
#          'value': 'us',
#          'description': 'US'},
#         {'type': 'registered_agent',
#          'name': 'Registered agent',
#          'rating': 'positive',
#          'value': 'not_registered_agent',
#          'description': 'Not a registered agent'},
#         {'type': 'private_mailbox',
#          'name': 'Private mailbox',
#          'rating': 'positive',
#          'value': 'not_private_mailbox',
#          'description': 'Not a private mailbox'},
#         {'type': 'location_frequency',
#          'name': 'Location frequency',
#          'rating': 'positive',
#          'value': '2-20_businesses',
#          'description': '2-20 businesses'},
#         {'type': 'property_type',
#          'name': 'Property type',
#          'rating': 'positive',
#          'value': 'commercial',
#          'description': 'Commercial'}],
#        'risk_rating': 'low'}},
#      {'object': 'address',
#       'address_line1': '2128 15th St Ste 100',
#       'address_line2': None,
#       'city': 'Denver',
#       'state': 'CO',
#       'postal_code': '80202-1067',
#       'full_address': '2128 15th St Ste 100, Denver, CO 80202-1067',
#       'submitted': False,
#       'id': '4ced7bc6-72d8-472b-b468-533496771ddb',
#       'latitude': 39.75384,
#       'longitude': -105.00603,
#       'property_type': 'COMMERCIAL',
#       'deliverable': True,
#       'deliverability_analysis': None,
#       'street_view_available': None,
#       'labels': [],
#       'created_at': '2025-08-07T16:31:30.632Z',
#       'updated_at': '2025-08-07T16:31:30.632Z',
#       'registered_agent_name': None,
#       'cmra': False,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'location_count': 21,
#       'is_registered_agent': False,
#       'sources': [{'id': 'e86a786d-9961-481a-926b-41c8acf93218',
#         'type': 'form_5500',
#         'metadata': {'ack_id': '20250717100726NAL0000087793001',
#          'labels': ['mailing'],
#          'plan_year': 2024}}],
#       'rating': {'indicators': [{'type': 'valid_us_address',
#          'name': 'Valid US address',
#          'rating': 'positive',
#          'value': 'valid',
#          'description': 'Valid'},
#         {'type': 'deliverability',
#          'name': 'Deliverability',
#          'rating': 'positive',
#          'value': 'deliverable',
#          'description': 'Deliverable'},
#         {'type': 'geographical_location',
#          'name': 'Geographical location',
#          'rating': 'positive',
#          'value': 'us',
#          'description': 'US'},
#         {'type': 'registered_agent',
#          'name': 'Registered agent',
#          'rating': 'positive',
#          'value': 'not_registered_agent',
#          'description': 'Not a registered agent'},
#         {'type': 'private_mailbox',
#          'name': 'Private mailbox',
#          'rating': 'positive',
#          'value': 'not_private_mailbox',
#          'description': 'Not a private mailbox'},
#         {'type': 'location_frequency',
#          'name': 'Location frequency',
#          'rating': 'neutral',
#          'value': '21-100_businesses',
#          'description': '21-100 businesses'},
#         {'type': 'property_type',
#          'name': 'Property type',
#          'rating': 'positive',
#          'value': 'commercial',
#          'description': 'Commercial'}],
#        'risk_rating': 'moderate'}},
#      {'object': 'address',
#       'address_line1': '4030 Wake Forest Rd Ste 349',
#       'address_line2': None,
#       'city': 'Raleigh',
#       'state': 'NC',
#       'postal_code': '27609-0010',
#       'full_address': '4030 Wake Forest Rd Ste 349, Raleigh, NC 27609-0010',
#       'submitted': False,
#       'id': '348e2cd7-fbfc-41d3-bf4d-c0119ef72053',
#       'latitude': 35.83628845214844,
#       'longitude': -78.61595153808594,
#       'property_type': 'COMMERCIAL',
#       'deliverable': True,
#       'deliverability_analysis': None,
#       'street_view_available': None,
#       'labels': [],
#       'created_at': '2025-08-07T16:31:28.119Z',
#       'updated_at': '2025-08-07T16:31:28.119Z',
#       'registered_agent_name': None,
#       'cmra': False,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'location_count': 10001,
#       'is_registered_agent': True,
#       'sources': [{'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#         'type': 'registration',
#         'metadata': {'state': 'NC',
#          'labels': ['registered_agent'],
#          'status': 'active',
#          'file_number': '2212862',
#          'jurisdiction': 'FOREIGN'}}],
#       'rating': {'indicators': [{'type': 'valid_us_address',
#          'name': 'Valid US address',
#          'rating': 'positive',
#          'value': 'valid',
#          'description': 'Valid'},
#         {'type': 'deliverability',
#          'name': 'Deliverability',
#          'rating': 'positive',
#          'value': 'deliverable',
#          'description': 'Deliverable'},
#         {'type': 'geographical_location',
#          'name': 'Geographical location',
#          'rating': 'positive',
#          'value': 'us',
#          'description': 'US'},
#         {'type': 'registered_agent',
#          'name': 'Registered agent',
#          'rating': 'negative',
#          'value': 'registered_agent',
#          'description': 'Registered agent'},
#         {'type': 'private_mailbox',
#          'name': 'Private mailbox',
#          'rating': 'positive',
#          'value': 'not_private_mailbox',
#          'description': 'Not a private mailbox'},
#         {'type': 'location_frequency',
#          'name': 'Location frequency',
#          'rating': 'negative',
#          'value': '10001+_businesses',
#          'description': '10001+ businesses'},
#         {'type': 'property_type',
#          'name': 'Property type',
#          'rating': 'positive',
#          'value': 'commercial',
#          'description': 'Commercial'}],
#        'risk_rating': 'high'}}],
#     'people': [{'object': 'person',
#       'name': 'Joseph Conrad',
#       'submitted': True,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [{'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#         'type': 'registration',
#         'metadata': {'state': 'FL',
#          'status': 'inactive',
#          'file_number': 'F19000001856',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#         'type': 'registration',
#         'metadata': {'state': 'NC',
#          'status': 'active',
#          'file_number': '2212862',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': '2d116386-a7c2-4012-815a-56c6e4f22f8b',
#         'type': 'registration',
#         'metadata': {'state': 'CO',
#          'status': 'active',
#          'file_number': '19911088860',
#          'jurisdiction': 'DOMESTIC'}},
#        {'id': 'cd45037e-591c-4d3d-a32f-bdd70b23eeea',
#         'type': 'registration',
#         'metadata': {'state': 'RI',
#          'status': 'inactive',
#          'file_number': '1018589',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#         'type': 'registration',
#         'metadata': {'state': 'KY',
#          'status': 'inactive',
#          'file_number': '1245663',
#          'jurisdiction': 'FOREIGN'}}],
#       'titles': [{'object': 'person_title', 'title': 'CHAIRMAN'},
#        {'object': 'person_title', 'title': 'CHIEF EXECUTIVE OFFICER'},
#        {'object': 'person_title', 'title': 'PRESIDENT'},
#        {'object': 'person_title', 'title': 'REGISTERED AGENT'}],
#       'people_bankruptcies': []},
#      {'object': 'person',
#       'name': 'Cole Pelayo',
#       'submitted': True,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [],
#       'titles': [],
#       'people_bankruptcies': []},
#      {'object': 'person',
#       'name': 'Erin Conrrad',
#       'submitted': True,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [],
#       'titles': [],
#       'people_bankruptcies': []},
#      {'object': 'person',
#       'name': 'SHEARER NORMAN',
#       'submitted': False,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [{'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#         'type': 'registration',
#         'metadata': {'state': 'FL',
#          'status': 'inactive',
#          'file_number': 'F19000001856',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': 'cd45037e-591c-4d3d-a32f-bdd70b23eeea',
#         'type': 'registration',
#         'metadata': {'state': 'RI',
#          'status': 'inactive',
#          'file_number': '1018589',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#         'type': 'registration',
#         'metadata': {'state': 'KY',
#          'status': 'inactive',
#          'file_number': '1245663',
#          'jurisdiction': 'FOREIGN'}}],
#       'titles': [{'object': 'person_title', 'title': 'CCO'},
#        {'object': 'person_title', 'title': 'PARTNER'}],
#       'people_bankruptcies': []},
#      {'object': 'person',
#       'name': 'KRISTINA K BYERS',
#       'submitted': False,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [{'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#         'type': 'registration',
#         'metadata': {'state': 'FL',
#          'status': 'inactive',
#          'file_number': 'F19000001856',
#          'jurisdiction': 'FOREIGN'}},
#        {'id': 'cd45037e-591c-4d3d-a32f-bdd70b23eeea',
#         'type': 'registration',
#         'metadata': {'state': 'RI',
#          'status': 'inactive',
#          'file_number': '1018589',
#          'jurisdiction': 'FOREIGN'}}],
#       'titles': [{'object': 'person_title', 'title': 'CFO'},
#        {'object': 'person_title', 'title': 'DIRECTOR'}],
#       'people_bankruptcies': []},
#      {'object': 'person',
#       'name': 'SOMERON LISA V',
#       'submitted': False,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [{'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#         'type': 'registration',
#         'metadata': {'state': 'FL',
#          'status': 'inactive',
#          'file_number': 'F19000001856',
#          'jurisdiction': 'FOREIGN'}}],
#       'titles': [{'object': 'person_title', 'title': 'DIRECTOR'}],
#       'people_bankruptcies': []},
#      {'object': 'person',
#       'name': 'KY SECRETARY OF STATE',
#       'submitted': False,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [{'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#         'type': 'registration',
#         'metadata': {'state': 'KY',
#          'status': 'inactive',
#          'file_number': '1245663',
#          'jurisdiction': 'FOREIGN'}}],
#       'titles': [{'object': 'person_title', 'title': 'REGISTERED AGENT'}],
#       'people_bankruptcies': []},
#      {'object': 'person',
#       'name': 'Graham, Jeff',
#       'submitted': False,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [{'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#         'type': 'registration',
#         'metadata': {'state': 'NC',
#          'status': 'active',
#          'file_number': '2212862',
#          'jurisdiction': 'FOREIGN'}}],
#       'titles': [{'object': 'person_title', 'title': 'TREASURER'}],
#       'people_bankruptcies': []},
#      {'object': 'person',
#       'name': 'VanSomeren, Lisa',
#       'submitted': False,
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'sources': [{'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#         'type': 'registration',
#         'metadata': {'state': 'NC',
#          'status': 'active',
#          'file_number': '2212862',
#          'jurisdiction': 'FOREIGN'}}],
#       'titles': [{'object': 'person_title', 'title': 'SECRETARY'}],
#       'people_bankruptcies': []}],
#     'phone_numbers': [],
#     'profiles': [{'object': 'profile',
#       'type': 'google',
#       'id': '1e57605a-15fd-4b78-9e2d-f38386eb6128',
#       'external_id': '10243062161681265383',
#       'url': 'https://maps.google.com/?cid=10243062161681265383',
#       'metadata': {'full_address': '2128 15th St, Denver, CO 80202',
#        'name': 'Cactus',
#        'website_urls': ['http://www.cactusinc.com/'],
#        'latitude': 39.7540361,
#        'longitude': -105.0063424,
#        'phone_number': '(303) 455-7545\n',
#        'categories': ['Advertising agency'],
#        'reviews': [{'text': 'If you are a person of color please don’t spend your money here. I needed advertising for my small business.. I parked my car and answered a text message..before I could get out the car (the owner) comes out to my vehicle to tell me to leave..than called me out my name when I ask him to continue what he was doing and leave me alone..demanded to know who I was and who I was there to see..horrible just horrible! 0 stars',
#          'rating': 1,
#          'posted_at': '2021-10-12T11:12:09.831Z'},
#         {'text': 'About the coolest people and "office" in all of Denver advertising...',
#          'rating': 5,
#          'posted_at': '2016-11-19T20:19:29.629Z'},
#         {'text': 'Professional, current, socially conscious.',
#          'rating': 5,
#          'posted_at': '2022-06-25T20:03:13.849Z'},
#         {'rating': 5, 'posted_at': '2022-01-30T20:02:42.107Z'},
#         {'rating': 1, 'posted_at': '2021-06-02T01:04:37.782Z'},
#         {'rating': 5, 'posted_at': '2023-02-21T03:09:58.610Z'},
#         {'rating': 5, 'posted_at': '2023-01-11T02:38:10.261Z'},
#         {'rating': 5, 'posted_at': '2019-09-28T12:13:57.723Z'}]},
#       'rating': 4.1,
#       'rating_count': 9}],
#     'registrations': [{'object': 'registration',
#       'id': '2d116386-a7c2-4012-815a-56c6e4f22f8b',
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'name': 'CACTUS COMMUNICATIONS INC.',
#       'status': 'active',
#       'sub_status': 'GOOD_STANDING',
#       'status_details': 'Good Standing',
#       'jurisdiction': 'DOMESTIC',
#       'entity_type': 'CORPORATION',
#       'file_number': '19911088860',
#       'addresses': ['2128 15TH ST, DENVER, CO 80202-6125'],
#       'officers': [],
#       'registered_agent': {'name': 'Joseph Conrad'},
#       'registration_date': '1991-11-05',
#       'state': 'CO',
#       'source': 'https://www.sos.state.co.us/biz/BusinessEntityCriteriaExt.do'},
#      {'object': 'registration',
#       'id': 'ab0c6dac-3ae6-4739-986a-b071c10dcc6a',
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'name': 'Cactus Communications Inc.',
#       'status': 'active',
#       'sub_status': 'GOOD_STANDING',
#       'status_details': 'Current-Active',
#       'jurisdiction': 'FOREIGN',
#       'entity_type': 'CORPORATION',
#       'file_number': '2212862',
#       'addresses': ['2128 15TH ST, DENVER, CO 80202-6125',
#        '4030 WAKE FOREST RD STE 349, RALEIGH, NC 27609-0010'],
#       'officers': [{'name': 'CONRAD, JOSEPH', 'roles': ['President']},
#        {'name': 'GRAHAM, JEFF', 'roles': ['Treasurer']},
#        {'name': 'VANSOMEREN, LISA', 'roles': ['Secretary']}],
#       'registered_agent': {},
#       'registration_date': '2021-06-14',
#       'state': 'NC',
#       'source': 'https://www.sosnc.gov/online_services/search/by_title/_lobbying'},
#      {'object': 'registration',
#       'id': 'b00fa863-1122-4f8e-8790-0046a85b012d',
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'name': 'CACTUS COMMUNICATIONS INC.',
#       'status': 'inactive',
#       'sub_status': None,
#       'status_details': None,
#       'jurisdiction': 'FOREIGN',
#       'entity_type': 'CORPORATION',
#       'file_number': 'F19000001856',
#       'addresses': ['2128 15TH ST, DENVER, CO 80202-6125'],
#       'officers': [{'name': 'BYERS KRISTINA', 'roles': ['Director']},
#        {'name': 'CONRAD JOSEPH', 'roles': ['Chairman']},
#        {'name': 'SHEARER NORMAN'},
#        {'name': 'SOMERON LISA V', 'roles': ['Director']}],
#       'registered_agent': {},
#       'registration_date': '2019-04-15',
#       'state': 'FL',
#       'source': 'http://search.sunbiz.org/Inquiry/CorporationSearch/ByName'},
#      {'object': 'registration',
#       'id': '187bb95b-acf4-469d-96bf-01faf59600bf',
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'name': 'CACTUS COMMUNICATIONS, INC',
#       'status': 'inactive',
#       'sub_status': None,
#       'status_details': 'Inactive',
#       'jurisdiction': 'FOREIGN',
#       'entity_type': 'CORPORATION',
#       'file_number': '1245663',
#       'addresses': ['1025 CAPITAL CENTER DR STE 201, FRANKFORT, KY 40601-8205',
#        '2128 15TH ST, DENVER, CO 80202-6125'],
#       'officers': [{'name': 'JOSEPH P CONRAD',
#         'roles': ['Chief Executive Officer']},
#        {'name': 'NORMAN SHEARER', 'roles': ['Partner']}],
#       'registered_agent': {'name': 'KY SECRETARY OF STATE'},
#       'registration_date': '2022-12-06',
#       'state': 'KY',
#       'source': 'https://sosbes.sos.ky.gov/BusSearchNProfile/search.aspx'},
#      {'object': 'registration',
#       'id': 'cd45037e-591c-4d3d-a32f-bdd70b23eeea',
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'name': 'Cactus Communications, Inc.',
#       'status': 'inactive',
#       'sub_status': None,
#       'status_details': 'Withdrawn',
#       'jurisdiction': 'FOREIGN',
#       'entity_type': 'CORPORATION',
#       'file_number': '1018589',
#       'addresses': ['2128 15TH ST, DENVER, CO 80202-6125'],
#       'officers': [{'name': 'JOSEPH P. CONRAD', 'roles': ['PRESIDENT']},
#        {'name': 'KRISTINA K BYERS', 'roles': ['CFO']},
#        {'name': 'NORMAN SHEARER', 'roles': ['CCO']}],
#       'registered_agent': {},
#       'registration_date': '2014-12-08',
#       'state': 'RI',
#       'source': 'http://business.sos.ri.gov/CorpWeb/CorpSearch/CorpSearch.aspx'}],
#     'orders': [{'object': 'order',
#       'id': 'e50f9639-437a-4447-b2fb-121a3d2083d7',
#       'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#       'completed_at': '2025-08-07T16:31:30.649Z',
#       'created_at': '2025-08-07T16:31:27.696Z',
#       'monitoring': False,
#       'product': 'tin',
#       'package': 'tin',
#       'requester': {'name': 'OnTop', 'type': 'account'},
#       'status': 'completed',
# ...
#        'text': "WORK\nABOUT\nSERVICES\nPEOPLE\nCONTACT\nABOUT\nOur Story\nCactus was founded on the belief that creativity and innovation can solve some of the world’s biggest problems.\nCONTACT US\nOur shared commitment is to work for brands, causes and organizations that move the world forward. Our name was inspired by a drive through the high desert, with cacti stretching for miles in every direction. Then came a bolt of inspiration: “Cactus – Sharp Ideas That Hold Water”.\xa0 It was a promise to deliver smart, creative solutions that made an impact. The name stuck, and a remarkable, innovative agency was planted in Colorado.\nOver the years, we developed a specialty in behavior change campaigns. Tackling the most daunting challenges you can imagine - mental health, smoking cessation, suicide prevention, the fentanyl crisis. This work fueled our conviction that behavior change is the metric that matters most, and that any brand can benefit from behavior change thinking.\nHow We Do It:\nBELIEF & BEHAVIOR DESIGN®\nWe use a proprietary planning process called Belief & Behavior Design® built on our experience using behavior change models, behavioral economics and consumer psychology, and we use it to solve business problems. Belief & Behavior Design® is our process for getting to great work at Cactus across our strategic, creative and media services, and creating consumer behavior change that sticks.\nThese are our superpowers.\nSTRATEGY\nCapabilities:\nCREATIVE\nCapabilities:\nMEDIA\nCapabilities:\nCONTACT US\nBRANDS WE'VE PARTNERED WITH\nGot a business problem we can solve? Let's talk.\nCONTACT US\nCONTACT\nCAREERS\nPRIVACY POLICY\nACCESSIBILITY\nSIGN UP FOR OUR NEWSLETTER\nSUBMIT\nCACTUS\n2128 15TH ST.\nDENVER, CO. 80202"},
#       {'url': 'https://cactusinc.com/people',
#        'category': 'careers',
#        'screenshot_url': 'https://static.middesk.com/websites/cactusinc.com/screenshots/careers--1754584312.png',
#        'text': "WORK\nABOUT\nSERVICES\nPEOPLE\nCONTACT\nPEOPLE\nCHARACTERISTICS OF A CACTI\n01. PASSION\n02. COURAGE\n03. TENACITY\n04. COLLABORATION\n05. RESPECT\n06. CRITICAL THOUGHT\n07. BELONGING\n08. WELL-BEING\nOur Agency Values\nCHARACTERISTICS OF A CACTI\nWe believe creating high-quality work requires attracting (and retaining) high-quality humans who exhibit the intangibles of strong character. At Cactus, there are eight values we teach out to our team, and expect from each other every day: Passion, Tenacity, Respect, Courage, Critical Thought, Collaboration, Belonging, and Wellbeing. More than words on a page - we annually rate the agency, and one another, on how well we’re living these out.\nSEE OUR VALUES\n01. PASSION\nA strong and consistent desire for achieving excellence that manifests in the form of dedicated effort, constant improvement, contagious optimism, and an energetic attitude.\nPREVIOUSNEXT\n02. COURAGE\nThe ability to embrace being uncomfortable, and the willingness to stand out, take risks, and engage in respectful confrontation for the sake of championing excellence in our work and in those around us.\nPREVIOUSNEXT\n03. TENACITY\nA mindset that is steadfastly proactive and solution-oriented in the face of challenges; a perpetual intolerance for complacency.\nPREVIOUSNEXT\n04. COLLABORATION\nA regular pattern of behavior that is unwaveringly team-oriented, and which demonstrates an eagerness to generate ideas and solutions in partnership with others, placing high value on open-mindedness and welcoming the input, evaluation, and feedback of others into your work.\nPREVIOUSNEXT\n05. RESPECT\nA lived attitude that is easily distinguished by the regular practice of valuing the roles, talents, efforts, contributions, and points of view of those around you, showing gratitude, appreciation, and professionalism in all circumstances – especially when you disagree.\nPREVIOUSNEXT\n06. CRITICAL THOUGHT\nA practiced commitment to asking critical questions at every turn, taking nothing on assumption, and never being afraid to voice a question, concern, or critique – all out of a determination to achieve excellence in every aspect of what we do.\nPREVIOUSNEXT\n07. BELONGING\nA palpable sense of inclusion and acceptance generated by a shared appreciation for the diverse perspectives, backgrounds, convictions and life experiences of others, along with the shared belief that what makes a person unique to the world around them is also what gives them their unique creative voice.\nPREVIOUSNEXT\n08. WELL-BEING\nA shared expectation for prioritizing and supporting one another’s mental, emotional, and physical welfare; caring about one another’s personal health just as much as we care about each other’s professional performance.\nPREVIOUSNEXT\nMEET THE CACTI\nFounder & CEO\nJOE CONRAD\nChief Creative Officer\nBRIAN WATSON\nVP, Account Leadership & People\nAINSLIE FORTUNE\nVP, Business Operations\nLISA VAN SOMEREN\nVP, Media & Digital\nCHRIS SHEWMAKE\nExecutive Creative Director\nSHEA TULLOS\nGroup Strategy Director\nBRIAN O'CONNELL\nExecutive Growth Director\nJILL KELLEMAN\nFinance Director\nCOLE PELAYO\nAccount Director\nDANIELLE DEATS\nBelief That Will Never Change:\nBehavior that probably should:\nOur Culture\nDO SOMETHING THAT MEANS SOMETHING.\nThe Cacti are our culture, all 70 of em. And they tell us Cactus is a place where they feel a genuine sense of belonging; a place where they can do meaningful work for clients they believe in - and have a lot of fun doing it. Maybe it's why Outside magazine named Cactus a ‘Best Place To Work’ three years running. Or why we have team members who’ve worked here 15, 20, even 25 years - many who’ve boomeranged back to Cactus. It’s all pretty unheard of in today’s agency world. But then, so is the culture we have at Cactus.\nDIVERSITY & BELONGING\nWhat makes a person unique to the world around them is also what gives them their unique creative voice.\nCactus has always been an equal  ...
#      'parked': False,
#      'submitted': True,
#      'error': None,
#      'category': 'Standard',
#      'platform': None,
#      'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#      'business_name_match': False,
#      'phone_numbers': [],
#      'people': None,
#      'addresses': [{'object': 'address',
#        'address_line1': '2128 15th St',
#        'address_line2': None,
#        'city': 'Denver',
#        'state': 'CO',
#        'postal_code': '80202-6125',
#        'full_address': '2128 15th St, Denver, CO 80202-6125',
#        'submitted': True,
#        'id': '013aab85-4f39-40aa-a87d-453d9ddaf00e'}],
#      'email_addresses': None}}]},
#  'formatted_responses': {'Middesk': {'data': {'review_flags': {'name': 'Success',
#      'address': 'Success',
#      'people': 'Success',
#      'sos': 'Success',
#      'tin': 'Success',
#      'watchlist': 'Success',
#      'website': 'Success',
#      'industry': 'Success',
#      'website_verification': 'Success',
#      'website_status': 'Success',
#      'website_parked': 'No Flag',
#      'website_url_discovered': 'No Flag',
#      'web_address_verification': 'No Flag',
#      'web_business_name_verification': 'No Flag',
#      'web_person_verification': 'No Flag',
#      'web_phone_number_verification': 'No Flag',
#      'web_email_address_verification': 'No Flag',
#      'web_presence_quality': 'No Flag',
#      'website_url_domain_ownership': 'No Flag'},
#     'search_status': 'In Review',
#     'search_complete': True,
#     'sos_match': 'success',
#     'sos_status': 'active',
#     'business_address_type': 'commercial',
#     'months_in_business': 405,
#     'authorized_signers_found': 0,
#     'authorized_signers_unfound': 0,
#     'principal_owners_found': 1,
#     'principal_owners_unfound': 2,
#     'high_risk_industries': [],
#     'naics_codes': ['541810', '541611'],
#     'mcc_codes': ['7311'],
#     'top_industry_category': 'ADVERTISING_AGENCIES',
#     'top_industry_high_risk': False,
#     'watchlist_hits_count': 0,
#     'business_name_partial_result': True,
#     'business_name_edit_distance': 0,
#     'business_address_partial_result': False,
#     'business_address_subset_match': False,
#     'business_name_fuzzy_match': False,
#     'sos_active_filing': True,
#     'selected_registration_states': False,
#     'registered_states': 'CO,FL,KY,NC,RI',
#     'watchlist': {'denied_person_hit': False,
#      'itar_debarred_hit': False,
#      'ssi_hit': False,
#      'foreign_sanctions_evaders_hit': False,
#      'ns_cmic_hit': False,
#      'entity_list_hit': False,
#      'plc_hit': False,
#      'unverified_list_hit': False,
#      'military_end_user_hit': False,
#      'ns_isa_hit': False,
#      'ns_mbs_hit': False,
#      'nonpro_sanctions_hit': False,
#      'sdn_hit': False,
#      'capta_list_hit': False},
#     'sos_domestic': {'sub_label': 'Domestic Active'},
#     'registrations': {'submitted_state_active': {'sub_status': 'GOOD_STANDING'}},
#     'website_verification': 'success',
#     'liens': {'closed_count': None,
#      'open_federal_liens_filed_within_2_year_count': 0,
#      'liens_filed_within_1_year_count': None,
#      'open_count': None,
#      'count': 0,
#      'liens_filed_over_1_year_ago_count': None,
#      'status': None},
#     'top_industry_category_naics_codes': {'code_2': {'value': None,
#       'length': 0},
#      'code_3': {'value': None, 'length': 0},
#      'code_1': {'length': 6, 'value': '541810'}},
#     'watchlists': {'isnull': False,
#      'isMissing': '[{"object":"watchlist_source","agency":"Office of Foreign Assets Control","agency_abbr":"OFAC","organization":"U.S. Department of Treasury","title":"Capta List","abbr":"CAP","results":[]},{"object":"watchlist_source","agency":"Bureau of Industry and Security","agency_abbr":"BIS","organization":"U.S. Department of Commerce","title":"Denied Persons List","abbr":"DPL","results":[]},{"object":"watchlist_source","agency":"Directorate of Defense Trade Controls","agency_abbr":"DDTC","organization":"U.S. Department of State","title":"AECA/ITAR Debarred","abbr":"DTC","results":[]},{"object":"watchlist_source","agency":"Bureau of Industry and Security","agency_abbr":"BIS","organization":"U.S. Department of Commerce","title":"Entity List","abbr":"EL","results":[]},{"object":"watchlist_source","agency":"Office of Foreign Assets Control","agency_abbr":"OFAC","organization":"U.S. Department of Treasury","title":"Foreign Sanctions Evaders","abbr":"FSE","results":[]},{"object":"watchlist_source","agency":"Bureau of International Security and Non-Proliferation","agency_abbr":"ISN","organization":"U.S. Department of State","title":"Nonproliferation Sanctions","abbr":"ISN","results":[]},{"object":"watchlist_source","agency":"Bureau of Industry and Security","agency_abbr":"BIS","organization":"U.S. Department of Commerce","title":"Military End User","abbr":"MEU","results":[]},{"object":"watchlist_source","agency":"Office of Foreign Assets Control","agency_abbr":"OFAC","organization":"U.S. Department of Treasury","title":"Non-SDN Chinese Military-Industrial Complex Companies List","abbr":"NS-CMIC","results":[]},{"object":"watchlist_source","agency":"Office of Foreign Assets Control","agency_abbr":"OFAC","organization":"U.S. Department of Treasury","title":"Non-SDN Iranian Sanctions","abbr":"NS-ISA","results":[]},{"object":"watchlist_source","agency":"Office of Foreign Assets Control","agency_abbr":"OFAC","organization":"U.S. Department of Treasury","title":"Non-SDN Menu-Based Sanctions","abbr":"NS-MBS","results":[]},{"object":"watchlist_source","agency":"Office of Foreign Assets Control","agency_abbr":"OFAC","organization":"U.S. Department of Treasury","title":"Palestinian Legislative Council","abbr":"PLC","results":[]},{"object":"watchlist_source","agency":"Office of Foreign Assets Control","agency_abbr":"OFAC","organization":"U.S. Department of Treasury","title":"Specially Designated Nationals","abbr":"SDN","results":[]},{"object":"watchlist_source","agency":"Office of Foreign Assets Control","agency_abbr":"OFAC","organization":"U.S. Department of Treasury","title":"Sectoral Sanctions Identifications","abbr":"SSI","results":[]},{"object":"watchlist_source","agency":"Bureau of Industry and Security","agency_abbr":"BIS","organization":"U.S. Department of Commerce","title":"Unverified List","abbr":"UVL","results":[]}]'},
#     'supported_document_types': None,
#     'governing_person_match': None,
#     'state_registrations_active': 'CO, NC',
#     'office_address_is_residential': None,
#     'address_is_private_mailbox': None,
#     'business_website_registrar_tld': '',
#     'litigations': {'count': 0, 'sublabel_found': None},
#     'address_undeliverable': False,
#     'sos_active_filing_status_sub_status': 'good_standing,good_standing',
#     'middesk_business_name_string': 'CACTUS COMMUNICATIONS INC.',
#     'registrant_match': False,
#     'sources': {'irs': {'name': 'CACTUS COMMUNICATIONS'},
#      'sos': {'date_of_incorporation_iso8601': '1991-11-05'}},
#     'registrations_file_number': '19911088860,2212862,F19000001856,1245663,1018589',
#     'tin_issued': True,
#     'entity_type': 'CORPORATION',
#     'governor_match': False,
#     'submitted_state_to_returned_state': True,
#     'office_address_is_cmra': None,
#     'has_industry_classification': True,
#     'property_type_commerial': True,
#     'secretary_match': False,
#     'business_id': '11fc4a1a-dddc-4f0f-8146-5a2cc78ae396',
#     'business_address_type_formatted_v2': 'Commercial',
#     'tin_match': {'sub_label': 'Found'},
#     'tin_verified': True,
#     'president_match': True,
#     'sos_sub_label': 'GOOD_STANDING',
#     'verified_representatives': '["Joseph Conrad"]',
#     'secondary_address_is_registered_agent': False,
#     'registrations_count': 5,
#     'secondary_is_residential': False,
#     'supported_document_types_count': 0,
#     'exactBusinessMatch': True,
#     'address_deliverability': 'success',
#     'sos_unknown_status': False,
#     'irs_unavailable_count': 0,
#     'state_registrations_unknown': '',
#     'formation': {'formation_state': 'CO',
#      'formation_date_exists': True,
#      'entity_type': None},
#     'address_is_virtual_address': False,
#     'secondary_is_cmra': False,
#     'office_address_sub_label': None,
#     'sos_status_sub_label': 'partially inactive, active',
#     'business_website_title': 'Cactus | Full-Service Advertising Agency | Creative | Strategy | Media',
#     'hasOpenLitigations': False,
#     'sos_active_and_domestic': True,
#     'sos_domestic_sub_status': {'status': 'success'},
#     'website_status': 'online',
#     'approximateBusinessAddressMatch': False,
#     'sos_inactive_status': 'warning',
#     'hasNegativeAdverseMediaSentiments': None,
#     'document_not_expired': None,
#     'business_name_sub_label': 'verified',
#     'registered_agent_names': 'Joseph Conrad,,,KY SECRETARY OF STATE,',
#     'submitted_address_is_registered_agent': False,
#     'registrations_in_nj_or_de': False,
#     'business_website_phone_number_count': 0,
#     'state_registrations_inactive': 'FL, KY, RI',
#     'submitted_address_matches_sos_registration': True,
#     'industry': {'sub_label': 'No Hits'},
#     'sos_match_sub_label': 'submitted active',
#     'person_verification': 'success',
#     'review_flag_representative': 'Verified',
#     'location_frequency': {'sub_label': 'Moderate frequency'},
#     'bankruptcy_past_36_months': None,
#     'cmra_address': False,
#     'address_verification': {'sub_label': 'Verified'},
#     'business_website_domain_age_days': 4775,
#     'governing_person_found': False,
#     'submitted_to_returned_postal_code': False,
#     'primary_address_is_deliverable': True,
#     'sos_domestic_status_sub_label': 'Good Standing',
#     'officers': '',
#     'manager_match': False,
#     'sos_registration_exists_submitted_business_address_state': True,
#     'bankruptcies': {'count_filed_in_past_2_years': 0}},
#    'matching': {'business_name': {'matched': True, 'score': 1},
#     'business_address': {'matched': True, 'score': 1},
#     'business_owner': {'matched': True, 'score': 1},
#     'business_fein': {'matched': True, 'score': 1}},
#    'empty_industry_classification_categories': False,
#    'dba_name_status': None}},
#  'audit_archive': None}
